# %% [markdown]
# # EDA — German Credit Dataset
# Exploracion inicial antes de modularizar en `src/`.

# %%
import sys
sys.path.insert(0, '../src')
from data_loader import load_german_credit

df = load_german_credit('../data/german-credit-data/german.data')
df.head()

# %%
df['target'].value_counts(normalize=True)
